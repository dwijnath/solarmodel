# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from tqdm import tqdm_notebook
from tqdm.notebook import tqdm
from itertools import product
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot

# %%
# Data inputs
# 1. Path where input file is stored
filepath = "C:/Users/patil/Desktop/Ganesh's Area/For paper/forpaperdataandscripts/0. From DD/0. From DD/Combined Dataset_v1.csv"

# 2. Row number of starting month
startrow_training = 0
endrow_training = 72
startrow_test = 72
endrow_test = 84

# 3. Dependent variable name
dependent_var = "AD_Daily_Avg_SR"

# 4. PArameter list for SARIMA Grid search
p = range(0, 4, 1)
d = 1
q = range(0, 4, 1)
P = range(0, 4, 1)
D = 1
Q = range(0, 4, 1)
s = 12

# %%
df = pd.read_csv(filepath)
df.index.name = 'Month_Year'
df.set_index(df['Month_Year'], inplace=False)
df.head()
# Out:
#             Day Month  Year  Month_Year  AD_Daily_Avg_SR  DXB_Daily_Avg_SR  \
# Month_Year
# 0             1   Jan  2013  1-Jan-2013          4342.58           4369.61
# 1             1   Feb  2013  1-Feb-2013          5370.00           5295.68
# 2             1   Mar  2013  1-Mar-2013          6360.97           6308.74
# 3             1   Apr  2013  1-Apr-2013          5955.33           6227.77
# 4             1   May  2013  1-May-2013          7551.61           7549.61
#
#             AD_Sunshine_Hours  DXB_Sunshine_Hours  AD_UV_Radiation
# Month_Year
# 0                        7.96                8.60              NaN
# 1                        8.88                9.03              NaN
# 2                        8.79                9.84              NaN
# 3                        8.21               10.33              NaN
# 4                       10.65               11.21              NaN

# %%
ts=df[dependent_var]
plt.plot(ts)
plt.ylabel(dependent_var)
plt.xlabel('Months')
plt.show()

# %%
ts.describe()
# Out:
# count      84.000000
# mean     6172.575357
# std      1209.593143
# min      4037.000000
# 25%      5205.302500
# 50%      6438.500000
# 75%      7247.502500
# max      8191.000000
# Name: AD_Daily_Avg_SR, dtype: float64

# %%
result_v1 = seasonal_decompose(ts, model='multiplicative',freq=12)
result_v1.plot()
pyplot.show()

# %%
ts_diff = pd.Series(ts)
dftest = adfuller(ts_diff)
dftest
# Results below show that series is not stationary
# P-value > 5% and ADF statistics is higher than critical values
# Out:
# (-1.835335169785957,
#  0.3630651739572138,
#  12,
#  71,
#  {'1%': -3.526004646825607,
#   '5%': -2.9032002348069774,
#   '10%': -2.5889948363419957},
#  1052.2083601988772)

# %%
df['Dependent_var_diff1'] = df[dependent_var] - df[dependent_var].shift(1)
df['Dependent_var_diff1'].plot(rot = 80, figsize = (14,8));

# %%
ts1  = df['Dependent_var_diff1']
ts_diff1 = pd.Series(ts1)
dftest1 = adfuller(ts_diff1.dropna())
dftest1
# Differenced Time series is stationary: P-value < 5% and ADF statistic lower than critical values
# Out:
# (-8.299576621844126,
#  4.052510896641745e-13,
#  9,
#  73,
#  {'1%': -3.5232835753964475,
#   '5%': -2.902030597326081,
#   '10%': -2.5883710883843123},
#  1038.0773503576163)

# %%
plot_acf(ts, lags = 48)
plot_pacf(ts, lags = 48)
plt.show()

# %%
# Divide the data into train and test datasets
train = df[dependent_var][startrow_training:endrow_training]
test = df[dependent_var][startrow_test:endrow_test]
train
# Out:
# Month_Year
# 0     4342.58
# 1     5370.00
# 2     6360.97
# 3     5955.33
# 4     7551.61
#        ...
# 67    6920.00
# 68    6640.00
# 69    5490.00
# 70    4690.00
# 71    4377.00
# Name: AD_Daily_Avg_SR, Length: 72, dtype: float64

# %%
test
# Out:
# Month_Year
# 72    4535.0
# 73    4829.0
# 74    5606.0
# 75    6406.0
# 76    7516.0
# 77    7680.0
# 78    7251.0
# 79    6997.0
# 80    6471.0
# 81    5662.0
# 82    4527.0
# 83    4037.0
# Name: AD_Daily_Avg_SR, dtype: float64

# %%
def optimize_sarima(parameters_list, d, D, s, data) :
    results = []
    
    for param in tqdm(parameters_list):
        try:
            model = SARIMAX(data, order=(param[0], d, param[1]),seasonal_order=(param[2], D, param[3], s),enforce_stationarity=False, enforce_invertibility=False).fit()
        except:
            continue
            
        aic = model.aic
        results.append([param, aic])
        
    result_df = pd.DataFrame(results)
    result_df.columns = ['(p,q)x(P,Q)', 'AIC']
    result_df = result_df.sort_values(by='AIC', ascending=True).reset_index(drop=True)
    
    return result_df

# %%
parameters = product(p, q, P, Q)
parameters_list = list(parameters)
print(len(parameters_list))
# Out:
# 256

# %%
warnings.simplefilter('ignore', ConvergenceWarning)
result_df = optimize_sarima(parameters_list, d, D, s, train)
result_df
# Out:
# HBox(children=(IntProgress(value=0, max=256), HTML(value='')))
#       (p,q)x(P,Q)         AIC
# 0    (3, 0, 3, 0)  273.676829
# 1    (3, 0, 3, 1)  275.550400
# 2    (3, 1, 3, 0)  278.293827
# 3    (2, 1, 3, 1)  283.778556
# 4    (3, 1, 3, 1)  285.174085
# ..            ...         ...
# 123  (0, 1, 0, 0)  877.105524
# 124  (2, 0, 0, 0)  877.685324
# 125  (2, 1, 0, 0)  879.553180
# 126  (1, 0, 0, 0)  893.683513
# 127  (0, 0, 0, 0)  894.893875
#
# [128 rows x 2 columns]

# %%
# Selected 4th set of parameters from the grid search above because of 2 reasons:
# 1. intuitively so that it is in line with the observations from ACF and PACF plots
# 2. This set gave better MAPE and RMSE for small difference in AIC values compared to first few cases
model_final = SARIMAX(train, order=(2, 1, 1),seasonal_order=(3, 1, 1, 12),enforce_stationarity=False, enforce_invertibility=False).fit()
aic_final = model_final.aic
aic_final
# Out:
# 283.7785557511421

# %%
fcast = model_final.get_prediction(start=1, end=len(train))
solarradiation_predict = fcast.predicted_mean
solarradiation_ci = fcast.conf_int()

# %%
plt.plot(solarradiation_predict,label='prediction')
plt.plot(train,color='red',label='actual')
plt.ylabel(dependent_var)
plt.xlabel('Months')
plt.legend()
plt.show()

# %%
print(model_final.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                    AD_Daily_Avg_SR   No. Observations:                   72
# Model:             SARIMAX(2, 1, 1)x(3, 1, 1, 12)   Log Likelihood                -133.889
# Date:                            Fri, 20 Nov 2020   AIC                            283.779
# Time:                                    15:21:40   BIC                            292.135
# Sample:                                         0   HQIC                           285.592
#                                              - 72
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5714      0.203     -2.815      0.005      -0.969      -0.174
# ar.L2         -0.2156      0.228     -0.944      0.345      -0.663       0.232
# ma.L1         -0.4343      0.381     -1.140      0.254      -1.181       0.312
# ar.S.L12      -0.5565      0.103     -5.385      0.000      -0.759      -0.354
# ar.S.L24      -0.5943      0.097     -6.097      0.000      -0.785      -0.403
# ar.S.L36       0.0187      0.263      0.071      0.943      -0.496       0.534
# ma.S.L12      -0.9978      0.485     -2.058      0.040      -1.948      -0.047
# sigma2      1.475e+04    3.3e-05   4.47e+08      0.000    1.48e+04    1.48e+04
# ===================================================================================
# Ljung-Box (Q):                         nan   Jarque-Bera (JB):                 0.74
# Prob(Q):                               nan   Prob(JB):                         0.69
# Heteroskedasticity (H):               1.90   Skew:                             0.20
# Prob(H) (two-sided):                  0.42   Kurtosis:                         2.17
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.12e+27. Standard errors may be unstable.

# %%
model_final.plot_diagnostics(lags=6,figsize=(15,8));

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 
            'corr':corr})

forecast_accuracy(solarradiation_predict, train)
# Out:
# {'mape': 0.07437814444578537,
#  'me': 48.993324210776095,
#  'mae': 429.012310691546,
#  'mpe': 0.01824888157910223,
#  'rmse': 672.4879652216447,
#  'corr': 0.7468259846094548}

# %%
# Forecast the values for validation dataset and check if the model generalizes well
fcast_test = model_final.get_prediction(start=72, end=95)
solarradiation_predict_test = fcast_test.predicted_mean
solarradiation_ci_test = fcast_test.conf_int()
plt.plot(solarradiation_predict_test,label='prediction')
plt.plot(test,color='red',label='actual')
plt.ylabel(dependent_var)
plt.xlabel('Months')
plt.legend()
plt.show()

# %%
forecast_accuracy(solarradiation_predict_test[:12], test)
# Out:
# {'mape': 0.09691221577517718,
#  'me': 475.3048783244279,
#  'mae': 518.4275144620107,
#  'mpe': 0.08740336546920523,
#  'rmse': 629.6413848841995,
#  'corr': 0.9411291206333138}
