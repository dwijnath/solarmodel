# %%
import pandas as pd
from pandas import read_csv
import numpy as np
from numpy import array
from datetime import datetime
import seaborn as sns
import matplotlib.pylab as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from tqdm import tqdm_notebook
from tqdm.notebook import tqdm
from itertools import product
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning
from statsmodels.tsa.seasonal import seasonal_decompose
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from sklearn.preprocessing import MinMaxScaler
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from numpy import concatenate

# %%
# Data inputs
# 1. PAth where input file is stored
filepath = "C:/Users/patil/Desktop/Ganesh's Area/For paper/forpaperdataandscripts/0. From DD/0. From DD/Combined Dataset_v1.csv"

# 2. Row number of starting month
startrow_training = 0
endrow_training = 72
startrow_test = 72
endrow_test = 84

# 3. Dependent variable name
dependent_var = "AD_Daily_Avg_SR"

# 4. Number of LSTM time steps 
n_steps = 3

# 5. Number of features. For a univariate series, the number of features is one, for one variable.
n_features = 1

# 6. Number of hidden LSTM layers
n_hidden = 1000

# 7. Number of epochs of stochastic gradient descent
n_epochs = 1000

# %%
df = pd.read_csv(filepath)
df.index.name = 'Month_Year'
df.set_index(df['Month_Year'], inplace=True)

# %%
df.head(20)
# Out:
#             Day Month  Year  Month_Year  AD_Daily_Avg_SR  DXB_Daily_Avg_SR  \
# Month_Year
# 1-Jan-2013    1   Jan  2013  1-Jan-2013          4342.58           4369.61
# 1-Feb-2013    1   Feb  2013  1-Feb-2013          5370.00           5295.68
# 1-Mar-2013    1   Mar  2013  1-Mar-2013          6360.97           6308.74
# 1-Apr-2013    1   Apr  2013  1-Apr-2013          5955.33           6227.77
# 1-May-2013    1   May  2013  1-May-2013          7551.61           7549.61
# 1-Jun-2013    1   Jun  2013  1-Jun-2013          7635.00           7396.70
# 1-Jul-2013    1   Jul  2013  1-Jul-2013          7221.29           7032.32
# 1-Aug-2013    1   Aug  2013  1-Aug-2013          6651.29           6355.84
# 1-Sep-2013    1   Sep  2013  1-Sep-2013          6594.33           6551.00
# 1-Oct-2013    1   Oct  2013  1-Oct-2013          5752.90           5741.84
# 1-Nov-2013    1   Nov  2013  1-Nov-2013          4481.00           4455.90
# 1-Dec-2013    1   Dec  2013  1-Dec-2013          4310.97           4393.35
# 1-Jan-2014    1   Jan  2014  1-Jan-2014          4134.52           4157.45
# 1-Feb-2014    1   Feb  2014  1-Feb-2014          5231.07           5198.57
# 1-Mar-2014    1   Mar  2014  1-Mar-2014          5980.32           5792.77
# 1-Apr-2014    1   Apr  2014  1-Apr-2014          7246.67           7250.00
# 1-May-2014    1   May  2014  1-May-2014          7568.06           7015.87
# 1-Jun-2014    1   Jun  2014  1-Jun-2014          7823.67           7236.17
# 1-Jul-2014    1   Jul  2014  1-Jul-2014          7326.13           7034.29
# 1-Aug-2014    1   Aug  2014  1-Aug-2014          7048.71           6742.97
#
#             AD_Sunshine_Hours  DXB_Sunshine_Hours  AD_UV_Radiation
# Month_Year
# 1-Jan-2013               7.96                8.60              NaN
# 1-Feb-2013               8.88                9.03              NaN
# 1-Mar-2013               8.79                9.84              NaN
# 1-Apr-2013               8.21               10.33              NaN
# 1-May-2013              10.65               11.21              NaN
# 1-Jun-2013              10.98               11.38              NaN
# 1-Jul-2013              10.70               11.22              NaN
# 1-Aug-2013               9.66               10.65              NaN
# 1-Sep-2013              10.12               10.27              NaN
# 1-Oct-2013               9.56                9.47              NaN
# 1-Nov-2013               8.06                8.73              NaN
# 1-Dec-2013               8.34                8.75              NaN
# 1-Jan-2014               7.30                8.30              NaN
# 1-Feb-2014               8.52                9.14              NaN
# 1-Mar-2014               8.80                9.50            179.2
# 1-Apr-2014              10.33               10.80            213.5
# 1-May-2014              10.90               10.89            213.3
# 1-Jun-2014              11.27               11.02            208.8
# 1-Jul-2014              10.55               11.17            198.7
# 1-Aug-2014              10.45               10.76            194.8

# %%
# Divide the data into train and test datasets
train = df[dependent_var][startrow_training:endrow_training]
test = df[dependent_var][startrow_test:endrow_test]
train
# Out:
# Month_Year
# 1-Jan-2013    4342.58
# 1-Feb-2013    5370.00
# 1-Mar-2013    6360.97
# 1-Apr-2013    5955.33
# 1-May-2013    7551.61
#                ...
# 1-Aug-2018    6920.00
# 1-Sep-2018    6640.00
# 1-Oct-2018    5490.00
# 1-Nov-2018    4690.00
# 1-Dec-2018    4377.00
# Name: AD_Daily_Avg_SR, Length: 72, dtype: float64

# %%
test
# Out:
# Month_Year
# 1-Jan-2019    4535.0
# 1-Feb-2019    4829.0
# 1-Mar-2019    5606.0
# 1-Apr-2019    6406.0
# 1-May-2019    7516.0
# 1-Jun-2019    7680.0
# 1-Jul-2019    7251.0
# 1-Aug-2019    6997.0
# 1-Sep-2019    6471.0
# 1-Oct-2019    5662.0
# 1-Nov-2019    4527.0
# 1-Dec-2019    4037.0
# Name: AD_Daily_Avg_SR, dtype: float64

# %%
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
colindex = df.columns.get_loc(dependent_var)
train_processed = df.iloc[startrow_training:endrow_training, colindex:colindex+1].values
#train_processed

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
train_data_scaled = scaler.fit_transform(train_processed)
#train_data_scaled

# %%
X, y = split_sequence(train_data_scaled, n_steps)
# summarize the data
for i in range(len(X)):
    print(X[i], y[i])
# Out:
# [[0.05129077]
#  [0.30456948]
#  [0.54886256]] [0.44886453]
# [[0.30456948]
#  [0.54886256]
#  [0.44886453]] [0.84237812]
# [[0.54886256]
#  [0.44886453]
#  [0.84237812]] [0.86293535]
# [[0.44886453]
#  [0.84237812]
#  [0.86293535]] [0.76094792]
# [[0.84237812]
#  [0.86293535]
#  [0.76094792]] [0.620432]
# [[0.86293535]
#  [0.76094792]
#  [0.620432  ]] [0.60639027]
# [[0.76094792]
#  [0.620432  ]
#  [0.60639027]] [0.39896166]
# [[0.620432  ]
#  [0.60639027]
#  [0.39896166]] [0.08541395]
# [[0.60639027]
#  [0.39896166]
#  [0.08541395]] [0.0434983]
# [[0.39896166]
#  [0.08541395]
#  [0.0434983 ]] [0.]
# [[0.08541395]
#  [0.0434983 ]
#  [0.        ]] [0.27032057]
# [[0.0434983 ]
#  [0.        ]
#  [0.27032057]] [0.45502505]
# [[0.        ]
#  [0.27032057]
#  [0.45502505]] [0.76720457]
# [[0.27032057]
#  [0.45502505]
#  [0.76720457]] [0.84643336]
# [[0.45502505]
#  [0.76720457]
#  [0.84643336]] [0.90944612]
# [[0.76720457]
#  [0.84643336]
#  [0.90944612]] [0.78679298]
# [[0.84643336]
#  [0.90944612]
#  [0.78679298]] [0.71840364]
# [[0.90944612]
#  [0.78679298]
#  [0.71840364]] [0.61345797]
# [[0.78679298]
#  [0.71840364]
#  [0.61345797]] [0.40612058]
# [[0.71840364]
#  [0.61345797]
#  [0.40612058]] [0.17366781]
# [[0.61345797]
#  [0.40612058]
#  [0.17366781]] [0.04628151]
# [[0.40612058]
#  [0.17366781]
#  [0.04628151]] [0.0950282]
# [[0.17366781]
#  [0.04628151]
#  [0.0950282 ]] [0.30851379]
# [[0.04628151]
#  [0.0950282 ]
#  [0.30851379]] [0.47466769]
# [[0.0950282 ]
#  [0.30851379]
#  [0.47466769]] [0.73795014]
# [[0.30851379]
#  [0.47466769]
#  [0.73795014]] [0.82152014]
# [[0.47466769]
#  [0.73795014]
#  [0.82152014]] [0.86490751]
# [[0.73795014]
#  [0.82152014]
#  [0.86490751]] [0.75348085]
# [[0.82152014]
#  [0.86490751]
#  [0.75348085]] [0.75397389]
# [[0.86490751]
#  [0.75348085]
#  [0.75397389]] [0.60236461]
# [[0.75348085]
#  [0.75397389]
#  [0.60236461]] [0.39380941]
# [[0.75397389]
#  [0.60236461]
#  [0.39380941]] [0.14531811]
# [[0.60236461]
#  [0.39380941]
#  [0.14531811]] [0.00349811]
# [[0.39380941]
#  [0.14531811]
#  [0.00349811]] [0.06298071]
# [[0.14531811]
#  [0.00349811]
#  [0.06298071]] [0.27054984]
# [[0.00349811]
#  [0.06298071]
#  [0.27054984]] [0.32182582]
# [[0.06298071]
#  [0.27054984]
#  [0.32182582]] [0.61099278]
# [[0.27054984]
#  [0.32182582]
#  [0.61099278]] [0.87649391]
# [[0.32182582]
#  [0.61099278]
#  [0.87649391]] [0.89621544]
# [[0.61099278]
#  [0.87649391]
#  [0.89621544]] [0.76802548]
# [[0.87649391]
#  [0.89621544]
#  [0.76802548]] [0.88832683]
# [[0.89621544]
#  [0.76802548]
#  [0.88832683]] [1.]
# [[0.76802548]
#  [0.88832683]
#  [1.        ]] [0.72907545]
# [[0.88832683]
#  [1.        ]
#  [0.72907545]] [0.47121642]
# [[1.        ]
#  [0.72907545]
#  [0.47121642]] [0.29470871]
# [[0.72907545]
#  [0.47121642]
#  [0.29470871]] [0.34302647]
# [[0.47121642]
#  [0.29470871]
#  [0.34302647]] [0.19733365]
# [[0.29470871]
#  [0.34302647]
#  [0.19733365]] [0.40465625]
# [[0.34302647]
#  [0.19733365]
#  [0.40465625]] [0.79612866]
# [[0.19733365]
#  [0.40465625]
#  [0.79612866]] [0.884136]
# [[0.40465625]
#  [0.79612866]
#  [0.884136  ]] [0.91174614]
# [[0.79612866]
#  [0.884136  ]
#  [0.91174614]] [0.77616061]
# [[0.884136  ]
#  [0.91174614]
#  [0.77616061]] [0.7502761]
# [[0.91174614]
#  [0.77616061]
#  [0.7502761 ]] [0.58781998]
# [[0.77616061]
#  [0.7502761 ]
#  [0.58781998]] [0.40490277]
# [[0.7502761 ]
#  [0.58781998]
#  [0.40490277]] [0.17835167]
# [[0.58781998]
#  [0.40490277]
#  [0.17835167]] [0.02600284]
# [[0.40490277]
#  [0.17835167]
#  [0.02600284]] [0.07777186]
# [[0.17835167]
#  [0.02600284]
#  [0.07777186]] [0.24491184]
# [[0.02600284]
#  [0.07777186]
#  [0.24491184]] [0.59127125]
# [[0.07777186]
#  [0.24491184]
#  [0.59127125]] [0.68839979]
# [[0.24491184]
#  [0.59127125]
#  [0.68839979]] [0.77492802]
# [[0.59127125]
#  [0.68839979]
#  [0.77492802]] [0.90509013]
# [[0.68839979]
#  [0.77492802]
#  [0.90509013]] [0.71255867]
# [[0.77492802]
#  [0.90509013]
#  [0.71255867]] [0.68667416]
# [[0.90509013]
#  [0.71255867]
#  [0.68667416]] [0.6176488]
# [[0.71255867]
#  [0.68667416]
#  [0.6176488 ]] [0.33415178]
# [[0.68667416]
#  [0.6176488 ]
#  [0.33415178]] [0.13693646]
# [[0.6176488 ]
#  [0.33415178]
#  [0.13693646]] [0.05977596]

# %%
import os
os.environ['PYTHONHASHSEED'] = '0'
import numpy as np
np.random.seed(12345)
import random as rn
rn.seed(12345)
import tensorflow as tf
tf.random.set_seed(12345)
# LSTM
# reshape from [samples, timesteps] into [samples, timesteps, features]
X = X.reshape((X.shape[0], X.shape[1], n_features))

# define model - RELU activation function, MSE as Loss function and Adam Gradient Descent as Optimizer
# 50 LSTM units in the hidden layer and an output layer that predicts a single numerical value
model = Sequential()
model.add(LSTM(n_hidden, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
model.add(LSTM(n_hidden, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# fit model
model.fit(X, y, epochs=n_epochs, verbose=0)
# Find predictions
yhat = model.predict(X, verbose=0)
print(yhat)
# Out:
# [[0.6500325 ]
#  [0.8025416 ]
#  [0.8820971 ]
#  [0.8104354 ]
#  [0.7016026 ]
#  [0.44902733]
#  [0.3687301 ]
#  [0.11275107]
#  [0.00785916]
#  [0.05488671]
#  [0.26580197]
#  [0.42582926]
#  [0.6278219 ]
#  [0.85598963]
#  [0.8521252 ]
#  [0.76741296]
#  [0.7375755 ]
#  [0.6201025 ]
#  [0.40450665]
#  [0.16165373]
#  [0.03973797]
#  [0.07040547]
#  [0.28505272]
#  [0.49831256]
#  [0.67205006]
#  [0.8750441 ]
#  [0.85948926]
#  [0.74726856]
#  [0.6859669 ]
#  [0.6604382 ]
#  [0.3809287 ]
#  [0.17433564]
#  [0.02552992]
#  [0.06022049]
#  [0.2655669 ]
#  [0.43813387]
#  [0.6131922 ]
#  [0.8535368 ]
#  [0.8827151 ]
#  [0.751477  ]
#  [0.73175836]
#  [0.9056488 ]
#  [0.77265537]
#  [0.60596216]
#  [0.29427192]
#  [0.33697018]
#  [0.18965459]
#  [0.3969675 ]
#  [0.7792258 ]
#  [0.8207916 ]
#  [0.85244197]
#  [0.7684844 ]
#  [0.7423813 ]
#  [0.67088604]
#  [0.3663799 ]
#  [0.1856896 ]
#  [0.02857281]
#  [0.06432468]
#  [0.26133257]
#  [0.4573755 ]
#  [0.67116594]
#  [0.7867304 ]
#  [0.8383288 ]
#  [0.7492372 ]
#  [0.58881485]
#  [0.55873024]
#  [0.37448272]
#  [0.11305808]
#  [0.06574725]]

# %%
# fit model
#model.fit(X, y, epochs=n_epochs, verbose=0)
# Find predictions
#yhat = model.predict(X, verbose=0)
#print(yhat)

# %%
predictions_train = scaler.inverse_transform(yhat)
Actual_train = scaler.inverse_transform(y)

# %%
plt.plot(predictions_train,label='prediction')
plt.plot(Actual_train,color='red',label='actual')
plt.ylabel(dependent_var)
plt.xlabel('Month')
plt.legend()
plt.show()

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 
            'corr':corr})

forecast_accuracy(predictions_train, Actual_train)
# Out:
# {'mape': 0.026043181115800156,
#  'me': -30.73652230525362,
#  'mae': 166.64472995923913,
#  'mpe': -0.003136671308862644,
#  'rmse': 244.05255937113296,
#  'corr': nan}

# %%
test_inputs_act = df[dependent_var][startrow_test - n_steps:endrow_test].values
test_inputs_act = test_inputs_act.reshape(-1,1)
test_inputs_act = scaler.transform(test_inputs_act)
test_inputs_act
# Out:
# array([[ 0.33415178],
#        [ 0.13693646],
#        [ 0.05977596],
#        [ 0.09872599],
#        [ 0.17120262],
#        [ 0.362748  ],
#        [ 0.55996332],
#        [ 0.83359957],
#        [ 0.87402871],
#        [ 0.768272  ],
#        [ 0.70565614],
#        [ 0.57598706],
#        [ 0.37655307],
#        [ 0.09675384],
#        [-0.02404055]])

# %%
test_inputs_act.shape
# Out:
# (15, 1)

# %%
test_features_act = []
for i in range(n_steps, test_inputs_act.shape[0]):
    test_features_act.append(test_inputs_act[i-n_steps:i, 0])
test_features_act
# Out:
# [array([0.33415178, 0.13693646, 0.05977596]),
#  array([0.13693646, 0.05977596, 0.09872599]),
#  array([0.05977596, 0.09872599, 0.17120262]),
#  array([0.09872599, 0.17120262, 0.362748  ]),
#  array([0.17120262, 0.362748  , 0.55996332]),
#  array([0.362748  , 0.55996332, 0.83359957]),
#  array([0.55996332, 0.83359957, 0.87402871]),
#  array([0.83359957, 0.87402871, 0.768272  ]),
#  array([0.87402871, 0.768272  , 0.70565614]),
#  array([0.768272  , 0.70565614, 0.57598706]),
#  array([0.70565614, 0.57598706, 0.37655307]),
#  array([0.57598706, 0.37655307, 0.09675384])]

# %%
test_features_act = np.array(test_features_act)
test_features_act = np.reshape(test_features_act, (test_features_act.shape[0], test_features_act.shape[1], 1))
predictions_act_test = model.predict(test_features_act)
predictions_act_test1 = scaler.inverse_transform(predictions_act_test)
predictions_act_test1
# Out:
# array([[4856.7495],
#        [5431.2495],
#        [6064.5117],
#        [6583.918 ],
#        [7202.998 ],
#        [7862.546 ],
#        [7346.9766],
#        [7045.3306],
#        [6509.3657],
#        [5508.1895],
#        [4780.2583],
#        [4140.6206]], dtype=float32)

# %%
test_data1 = df[dependent_var][startrow_test:endrow_test].values
plt.plot(predictions_act_test1,label='prediction')
plt.plot(test_data1,color='red',label='actual')
plt.ylabel([dependent_var])
plt.xlabel('Months')
plt.legend()
plt.show()

# %%
forecast_accuracy(predictions_act_test1[:,0], test_data1)
# Out:
# {'mape': 0.04212414166359118,
#  'me': 151.30948893229166,
#  'mae': 229.111572265625,
#  'mpe': 0.030655781528506978,
#  'rmse': 281.50817101581845,
#  'corr': 0.9829322696933581}

# %%
# Next we will try to predict the SR for months during testing period and period post that by using predictions from each step
test_output1 = []
test_inputs = df[dependent_var][startrow_test - n_steps:startrow_test].values
test_inputs = test_inputs.reshape(-1,1)
test_inputs = scaler.transform(test_inputs)
print("test_inputs", test_inputs)
test_inputs = test_inputs.reshape((1, n_steps, n_features))
test_prediction = model.predict(test_inputs, verbose=0)
#test_output1.append(test_prediction[0][0])
#test_prediction1 = test_prediction.reshape(-1,1)
test_output1.append(scaler.inverse_transform(test_prediction)[0][0])
print("test_output1",test_output1)
test_inputs2 = test_inputs.copy()
print("test input2",test_inputs2)
print("test prediction",scaler.inverse_transform(test_prediction)[0][0])
type(test_inputs2)

for i in range(1, 24):
    test_inputs3 = test_inputs2
    test_inputs3[0][0] = test_inputs2[0][1]
    test_inputs3[0][1] = test_inputs2[0][2]
    #test_inputs3[0][1] = test_prediction[0][0]
    test_inputs3[0][2] = test_prediction[0][0]
    print("test input 3", scaler.inverse_transform(test_inputs3[0]))
    test_prediction = model.predict(test_inputs3, verbose=0)
    #test_prediction1 = test_prediction.reshape(-1,1)
    print("Test Predictions", scaler.inverse_transform(test_prediction)[0][0])
    test_output1.append(scaler.inverse_transform(test_prediction)[0][0])
    test_inputs2 = test_inputs3

print("test_output1",test_output1)
# Out:
# test_inputs [[0.33415178]
#  [0.13693646]
#  [0.05977596]]
# test_output1 [4856.7495]
# test input2 [[[0.33415178]
#   [0.13693646]
#   [0.05977596]]]
# test prediction 4856.7495
# test input 3 [[4690.        ]
#  [4377.        ]
#  [4856.74947209]]
# Test Predictions 5791.3657
# test input 3 [[4377.        ]
#  [4856.74947209]
#  [5791.36547035]]
# Test Predictions 6508.8604
# test input 3 [[4856.74947209]
#  [5791.36547035]
#  [6508.86006581]]
# Test Predictions 7207.38
# test input 3 [[5791.36547035]
#  [6508.86006581]
#  [7207.37973328]]
# Test Predictions 7779.514
# test input 3 [[6508.86006581]
#  [7207.37973328]
#  [7779.51424505]]
# Test Predictions 7528.697
# test input 3 [[7207.37973328]
#  [7779.51424505]
#  [7528.69658974]]
# Test Predictions 7012.3794
# test input 3 [[7779.51424505]
#  [7528.69658974]
#  [7012.37936555]]
# Test Predictions 6620.7124
# test input 3 [[7528.69658974]
#  [7012.37936555]
#  [6620.71248932]]
# Test Predictions 5841.094
# test input 3 [[7012.37936555]
#  [6620.71248932]
#  [5841.09376414]]
# Test Predictions 4805.279
# test input 3 [[6620.71248932]
#  [5841.09376414]
#  [4805.27851255]]
# Test Predictions 4275.622
# test input 3 [[5841.09376414]
#  [4805.27851255]
#  [4275.62206763]]
# Test Predictions 4334.5254
# test input 3 [[4805.27851255]
#  [4275.62206763]
#  [4334.52566582]]
# Test Predictions 5113.873
# test input 3 [[4275.62206763]
#  [4334.52566582]
#  [5113.87312328]]
# Test Predictions 5932.8857
# test input 3 [[4334.52566582]
#  [5113.87312328]
#  [5932.88588656]]
# Test Predictions 6646.894
# test input 3 [[5113.87312328]
#  [5932.88588656]
#  [6646.89394161]]
# Test Predictions 7394.4937
# test input 3 [[5932.88588656]
#  [6646.89394161]
#  [7394.49379805]]
# Test Predictions 7774.588
# test input 3 [[6646.89394161]
#  [7394.49379805]
#  [7774.58811646]]
# Test Predictions 7335.7363
# test input 3 [[7394.49379805]
#  [7774.58811646]
#  [7335.73592069]]
# Test Predictions 7042.22
# test input 3 [[7774.58811646]
#  [7335.73592069]
#  [7042.21999278]]
# Test Predictions 6624.7676
# test input 3 [[7335.73592069]
#  [7042.21999278]
#  [6624.76746638]]
# Test Predictions 5780.6616
# test input 3 [[7042.21999278]
#  [6624.76746638]
#  [5780.66188799]]
# Test Predictions 4786.745
# test input 3 [[6624.76746638]
#  [5780.66188799]
#  [4786.74520494]]
# Test Predictions 4279.4077
# test input 3 [[5780.66188799]
#  [4786.74520494]
#  [4279.4076357 ]]
# Test Predictions 4394.2593
# test_output1 [4856.7495, 5791.3657, 6508.8604, 7207.38, 7779.514, 7528.697, 7012.3794, 6620.7124, 5841.094, 4805.279, 4275.622, 4334.5254, 5113.873, 5932.8857, 6646.894, 7394.4937, 7774.588, 7335.7363, 7042.22, 6624.7676, 5780.6616, 4786.745, 4279.4077, 4394.2593]

# %%
test_data = df[dependent_var][startrow_test:endrow_test].values
plt.plot(test_output1,label='prediction')
plt.plot(test_data,color='red',label='actual')
plt.ylabel([dependent_var])
plt.xlabel('Months')
plt.legend()
plt.show()

# %%
forecast_accuracy(test_output1[:12], test_data)
# Out:
# {'mape': 0.08964316315328591,
#  'me': 87.09822591145833,
#  'mae': 504.4676106770833,
#  'mpe': 0.021214800317116266,
#  'rmse': 581.6905162813412,
#  'corr': 0.8868063177577998}
